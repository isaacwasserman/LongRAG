# %%
# %load_ext autoreload
# %autoreload 2

from rag_components import *
#from aws_mixtral import mixtral
from llama_index.core.retrievers import VectorIndexRetriever
from concurrent.futures import ThreadPoolExecutor

from rich.progress import track

import re
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import json
import os
import time
import re

from llama_index.core import Settings, VectorStoreIndex, StorageContext, load_index_from_storage
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core.schema import TextNode
from llama_index.llms.openai import OpenAI

from datasets import load_dataset
import evaluate
import tiktoken
import numpy as np


from tqdm.auto import tqdm

# %%
import os


def get_subdirectories_without_underscore(directory):
    # List all entries in the directory
    entries = os.listdir(directory)
    # Filter entries to find directories without an underscore
    return [entry for entry in entries if "_" not in entry and os.path.isdir(os.path.join(directory, entry))]


# Specify the directory path
directory_path = r"C:\AbhiData\Desktop\UPennCourses\CIS 6200\Project\LongRAG\indices"

# Call the function and print the result
files_without_underscore = get_subdirectories_without_underscore(directory_path)
print(files_without_underscore)

# %%
import time

longdep_qa_ds = load_dataset("bigainlco/LooGLE", "longdep_qa", split="test")
for environment in longdep_qa_ds:
    context = environment["input"]
    title = environment["title"]
    if title in files_without_underscore:
        print(title)
        # index_title = f"{title}_chunksize64"
        # text_index = create_index_from_text_with_ids(context, index_title, chunk_size=64, chunk_overlap=10)
        print("Starting 128")
        index_title = f"{title}_chunksize128"
        text_index = create_index_from_text_with_ids(context, index_title, chunk_size=128, chunk_overlap=25)
        # time.sleep(60)
        print("Starting 256")
        index_title = f"{title}_chunksize256"
        text_index = create_index_from_text_with_ids(context, index_title, chunk_size=256, chunk_overlap=50)
        # time.sleep(60)
        print("Starting 512")
        index_title = f"{title}_chunksize512"
        text_index = create_index_from_text_with_ids(context, index_title, chunk_size=512, chunk_overlap=100)
        # time.sleep(60)
        print("Starting 2048")
        index_title = f"{title}_chunksize2048"
        text_index = create_index_from_text_with_ids(context, index_title, chunk_size=2048, chunk_overlap=400)
# Out:
# José Luis Picardo
# Starting 128
# Starting 256
# Starting 512
# Starting 2048
# Urban planning of Barcelona
# Starting 128
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7604\4167460865.py in <cell line: 0>()
#      10         print("Starting 128")
#      11         index_title = f"{title}_chunksize128"
# ---> 12         text_index = create_index_from_text_with_ids(context, index_title, chunk_size=128, chunk_overlap=25)
#      13         # time.sleep(60)
#      14         print("Starting 256")
#
# c:\AbhiData\Desktop\UPennCourses\CIS 6200\Project\LongRAG\rag_components.py in create_index_from_text_with_ids(text, index_title, chunk_size, chunk_overlap)
#     119     if index is None:
#     120         ids = [f"text_chunk_{i}" for i in range(len(chunks))]
# --> 121         index = create_index_from_chunks_with_ids(chunks, ids, index_title)
# ...
